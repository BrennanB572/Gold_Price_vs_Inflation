# %%
import pandas as pd
import numpy as np

# %%
inflation_rates = ('Resources/inflation_rates.csv')
inflation_rates_df = pd.read_csv(inflation_rates)
inflation_rates_df
# Out:
#            country  year currency  inflation rate
# 0            China  1993      CNY       14.610079
# 1            China  1994      CNY       24.256990
# 2            China  1995      CNY       16.791225
# 3            China  1996      CNY        8.313160
# 4            China  1997      CNY        2.786465
# ..             ...   ...      ...             ...
# 111  United States  2017      USD        2.130110
# 112  United States  2018      USD        2.442583
# 113  United States  2019      USD        1.812210
# 114  United States  2020      USD        1.233584
# 115  United States  2021      USD        4.697859
#
# [116 rows x 4 columns]

# %%
inflation_rates_df1 = inflation_rates_df[inflation_rates_df['year']>= 2013]
inflation_rates_df1
# Out:
#                 country  year currency  inflation rate
# 20                China  2013      CNY        2.621050
# 21                China  2014      CNY        1.921642
# 22                China  2015      CNY        1.437024
# 23                China  2016      CNY        2.000002
# 24                China  2017      CNY        1.593136
# 25                China  2018      CNY        2.074790
# 26                China  2019      CNY        2.899234
# 27                China  2020      CNY        2.419422
# 28                China  2021      CNY        0.981015
# 49       European Union  2013      EUR        1.219993
# 50       European Union  2014      EUR        0.199344
# 51       European Union  2015      EUR       -0.061645
# 52       European Union  2016      EUR        0.183335
# 53       European Union  2017      EUR        1.429107
# 54       European Union  2018      EUR        1.738609
# 55       European Union  2019      EUR        1.630523
# ...

# %%
inflation_rates_df1.to_csv('Resources/inflation_rates_2013-2021.csv', header=True)
